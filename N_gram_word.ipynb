# %% [markdown]
# <a href="https://colab.research.google.com/github/mohanreddy7979/IIY_IVSEM_IRS/blob/main/N_gram_word.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def generate_ngrams(word, n):
    word = '#' + word + '#'
    return set(word[i:i+n] for i in range(len(word) - n + 1))

def correct_spelling(word, dictionary, n=2):
    scores = []
    for d in dictionary:
        g1 = generate_ngrams(word, n)
        g2 = generate_ngrams(d, n)
        score = len(g1 & g2) / len(g1 | g2)
        scores.append((score, d))
    best_score, test_word = max(scores)
    return best_score, test_word

dictionary = ["computer","science","engineering","information",
              "technology","spelling","correction","program"]

misspelled = "tecnology"

score, result = correct_spelling(misspelled, dictionary)

print("misspelled word:", misspelled)
print("suggested correction:", result)
print("similarity score:", round(score, 2))
# Out:
# misspelled word: tecnology
# suggested correction: technology
# similarity score: 0.75
