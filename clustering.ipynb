# %% [markdown]
# <a href="https://colab.research.google.com/github/mohanreddy7979/IIY_IVSEM_IRS/blob/main/clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans

# Use a list, not a set
sentences = [
    "python programming language",
    "machine learning models",
]

# Vectorize the sentences
vec = TfidfVectorizer()
data = vec.fit_transform(sentences)

# Apply KMeans clustering
k = KMeans(n_clusters=2, random_state=42)
clusters = k.fit_predict(data)

print("Cluster Results:\n")

# Iterate properly
for i in range(len(sentences)):
    s = sentences[i]
    c = clusters[i]
    print("Sentence:", s)
    print("Cluster:", c)
    print()
# Out:
# Cluster Results:
#
# Sentence: python programming language
# Cluster: 0
#
# Sentence: machine learning models
# Cluster: 1
